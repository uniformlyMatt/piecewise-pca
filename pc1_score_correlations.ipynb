# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_auth = pd.read_excel('/media/Bibliometrics/matt analysis/pca/PCA_inputs_feb18.xlsx')
scores = pd.read_csv('../compare-dim-reduction/results/pc1_scores_all_models.csv')
pwpca_scores = pd.read_csv('bib_decorrelated_latent_space.csv')
comp = pd.read_csv('~/OneDrive/collab/Datasets/top_cited_scholars.csv')

# %%
df_auth.info()
scores.info()
comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Auid                      2230 non-null   int64
#  1   affil                     2230 non-null   object
#  2   indexed_name              2230 non-null   object
#  3   publication_duration      2230 non-null   int64
#  4   Article_sum               2230 non-null   int64
#  5   document_count            2230 non-null   int64
#  6   openaccess_sum            2230 non-null   int64
#  7   coauthor_count            2230 non-null   int64
#  8   author_count_mean         2230 non-null   float64
#  9   author_weight_mean        2230 non-null   float64
#  10  chw_author_position_mean  2230 non-null   float64
#  11  first_author_sum          2230 non-null   int64
#  12  last_author_sum           2230 non-null   int64
# ...

# %%
scores['PWPCA_PC1'] = pwpca_scores['PWPCA_PC1']
scores['PWPCA_PC2'] = pwpca_scores['PWPCA_PC2']
scores['Auid'] = df_auth['Auid']

df_match = pd.merge(left=scores, right=comp, on='Auid')
scores['ws_composite'] = comp['composite']
scores['ns_composite'] = comp['c (ns)']

# %%
df_match = df_match[['PCA_C_PC1', 'PCA_PC1', 'PLNPCA_PC1', 'c (ns)', 'composite']]

# %%
df_match.corr()
# Out:
#             PCA_C_PC1   PCA_PC1  PLNPCA_PC1    c (ns)  composite
# PCA_C_PC1    1.000000  0.981149    0.996566  0.617016   0.613255
# PCA_PC1      0.981149  1.000000    0.970972  0.627539   0.627581
# PLNPCA_PC1   0.996566  0.970972    1.000000  0.613141   0.610669
# c (ns)       0.617016  0.627539    0.613141  1.000000   0.991096
# composite    0.613255  0.627581    0.610669  0.991096   1.000000

# %%
scores.corr()
# Out:
#               PCA_C_PC1   PCA_PC1  PLNPCA_PC1  AE1_dim1  AE2_dim1  \
# PCA_C_PC1      1.000000  0.996077    0.998430  0.303121  0.633258
# PCA_PC1        0.996077  1.000000    0.994160  0.257876  0.668691
# PLNPCA_PC1     0.998430  0.994160    1.000000  0.299425  0.617944
# AE1_dim1       0.303121  0.257876    0.299425  1.000000 -0.242713
# AE2_dim1       0.633258  0.668691    0.617944 -0.242713  1.000000
# PWPCA_PC1     -0.163529 -0.156659   -0.165018 -0.104309 -0.004248
# PWPCA_PC2      0.206928  0.197832    0.205664  0.076326  0.120241
# Auid          -0.437845 -0.421431   -0.440646 -0.154560 -0.165154
# ws_composite   0.150550  0.141666    0.152913  0.102354 -0.008613
# ns_composite   0.150867  0.142232    0.153243  0.102330 -0.009131
#
#                  PWPCA_PC1     PWPCA_PC2      Auid  ws_composite  ns_composite
# PCA_C_PC1    -1.635293e-01  2.069284e-01 -0.437845      0.150550      0.150867
# PCA_PC1      -1.566594e-01  1.978319e-01 -0.421431      0.141666      0.142232
# ...
